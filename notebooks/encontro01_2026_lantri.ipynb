# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelrdealmeida/fundamentos/blob/main/notebooks/encontro01_2026_lantri.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introdução ao Pensamento computacional
#
# - Google Colab (notebook com codigo)
# - Github (versionamento)

# %% [markdown]
# ## Noções Gerais

# %%
print("Olá")
# Out:
# Olá

# %% [markdown]
# ## Fundamentos Programação

# %%
print(1+1)
# Out:
# 2
